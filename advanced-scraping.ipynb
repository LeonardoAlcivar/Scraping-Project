# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import perf_counter, sleep
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
from multiprocessing import Pool

# %%
START_URL = 'http://notasdecorte.es/zona/andalucia'

# %%
r = requests.get(START_URL)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
def get_university(soup):
    divisions = soup.find_all("div", class_ = "field-content")
    university = []
    count = 0
    for division in divisions:
        if count % 2 == 0:
            title = division.a.text
            university.append(title)
        count += 1
    return university

# %%
def get_province(soup):
    divisions1 = soup.find_all("div", class_ = "titul-list-provincia text-right")
    province = []
    for division in divisions1:
        title = division.strong.text
        province.append(title)
    return province

# %%
def get_modality(soup):
    divisions2 = soup.find_all("div", class_ = "titul-list-modalidad text-right")
    modality = []
    for division in divisions2:
        title = division.text
        modality.append(title)
    return modality

# %%
def get_grade(soup):
    divisions3 = soup.find_all("div", class_ = "titul-list-nota-corte-nota")
    grade = []
    for division in divisions3:
        title = division.text
        grade.append(title)
    return grade

# %%
def get_public(soup):   
    spans = soup.find_all("span", class_ = "label label-primary")
    public = []
    for span in spans:
        title = span.text
        public.append(title)
    return public

# %%
def get_degree(soup):    
    divisions4 = soup.select("div span a")
    degree = []
    count = 0
    for division in divisions4:
        if count % 2 == 0:
            title = division.text
            degree.append(title)
        count += 1
    return degree

# %%
def get_web(soup):
    spansweb = soup.select("span.views-field.views-field-field-yaq-facultad-web span.field-content")
    web = []
    for span in spansweb:
        title = span.text
        web.append(title)
    return web

# %%
def get_duration(soup):
    spansd = soup.select("div.views-field.views-field-field-duracion span.field-content")
    duration = []
    for span in spansd:
        title = span.text
        duration.append(title)
    return duration

# %%
def get_cost(soup):
    spansc = soup.select("div.views-field.views-field-field-precio-primer-ano span.field-content")
    cost = []
    for span in spansc:
        title = span.text
        cost.append(title)
    return cost

# %%
def aggregate(soup):
    data = [("University", get_university(soup)),("Degree",get_degree(soup)),("Grade",get_grade(soup)),
            ("Province", get_province(soup)),("Modality",get_modality(soup)),
            ("Public/Private",get_public(soup)), ("Web", get_web(soup)), ("Duration", get_duration(soup)),
            ("Cost",get_cost(soup))]
    data1 = []
    length = len(data[0][1])
    for element in data:
        if len(element[1]) == length:
            data1.append(element)
    df = pd.DataFrame.from_dict(dict(data1))
    return df

# %%
START_URL1 = 'http://notasdecorte.es/'

# %%
r = requests.get(START_URL1)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
col1 = soup.select("table.views-view-grid.cols-2 td.col-1.col-first div.field-content a")
col2 = soup.select("table.views-view-grid.cols-2 td.col-2.col-last div.field-content a")

# %%
# %%time
links = []
for col in col1:
    d = col["href"]
    link = "http://notasdecorte.es/" + d
    links.append(link)
    
for col in col2:
    d = col["href"]
    link = "http://notasdecorte.es/" + d
    links.append(link)
# Out:
# CPU times: user 28 µs, sys: 1e+03 ns, total: 29 µs
# Wall time: 32.9 µs

# %%
links
# Out:
# ['http://notasdecorte.es/zona/andalucia',
#  'http://notasdecorte.es/zona/aragon',
#  'http://notasdecorte.es/zona/asturias',
#  'http://notasdecorte.es/zona/cantabria',
#  'http://notasdecorte.es/zona/castilla-y-leon',
#  'http://notasdecorte.es/zona/castilla-la-mancha',
#  'http://notasdecorte.es/zona/cataluna',
#  'http://notasdecorte.es/zona/ceuta-y-melilla',
#  'http://notasdecorte.es/zona/extremadura',
#  'http://notasdecorte.es/zona/galicia',
#  'http://notasdecorte.es/zona/islas-baleares',
#  'http://notasdecorte.es/zona/islas-canarias',
#  'http://notasdecorte.es/zona/la-rioja',
#  'http://notasdecorte.es/zona/madrid',
#  'http://notasdecorte.es/zona/navarra',
#  'http://notasdecorte.es/zona/pais-vasco',
#  'http://notasdecorte.es/zona/region-de-murcia',
#  'http://notasdecorte.es/zona/valencia']

# %%
def linkscrape(url):
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    aggregate(soup).to_csv(url.rpartition("zona/")[2]+".csv", sep = ',', encoding = "utf-8")
    
    pass

# %%
linkscrape(links[2])

# %%
# %%time

with ThreadPoolExecutor(18) as pool:
    pool.map(linkscrape, links)
# Out:
# CPU times: user 4.71 s, sys: 195 ms, total: 4.9 s
# Wall time: 4.79 s

# %%
# %%time
for link in links:
    linkscrape(link)
# Out:
# CPU times: user 4.66 s, sys: 98.8 ms, total: 4.76 s
# Wall time: 13.7 s

# %%
# %%time
def aggregate2(soup):
    data = []
    with ThreadPoolExecutor(max_workers = 9) as pool:
        data.append(tuple(["University", pool.submit(get_university, soup).result()]))
        data.append(tuple(["Degree", pool.submit(get_degree, soup).result()]))
        data.append(tuple(["Grade", pool.submit(get_grade, soup).result()]))
        data.append(tuple(["Province", pool.submit(get_province, soup).result()]))
        data.append(tuple(["Public/Private", pool.submit(get_public, soup).result()]))
        data.append(tuple(["Modality", pool.submit(get_modality, soup).result()]))
        data.append(tuple(["Web", pool.submit(get_web, soup).result()]))
        data.append(tuple(["Duration", pool.submit(get_duration, soup).result()]))
        data.append(tuple(["Cost", pool.submit(get_cost, soup).result()]))
        
        #university = pool.submit(get_university, soup)
        #degree = pool.submit(get_degree, soup)
        #grade = pool.submit(get_grade, soup)
        #province = pool.submit(get_province, soup)
        #modality = pool.submit(get_modality, soup)
        #public = pool.submit(get_public, soup)
        #web = pool.submit(get_web, soup)
        #duration = pool.submit(get_duration, soup)
        #cost = pool.submit(get_cost, soup)

    #data = [("University", university.result()),("Degree", degree.result()),("Grade",grade.result()),
    #            ("Province", province.result()),("Modality", modality.result()),
    #            ("Public/Private", public.result()), ("Web", web.result()), ("Duration", duration.result()),
    #            ("Cost",cost.result())]
    data1 = []
    length = len(data[0][1])
    for element in data:
        if len(element[1]) == length:
            data1.append(element)
    df = pd.DataFrame.from_dict(dict(data1))

    return df
# Out:
# CPU times: user 8 µs, sys: 1 µs, total: 9 µs
# Wall time: 14.1 µs

# %%
# %%time
aggregate2(soup)
# Out:
# CPU times: user 189 ms, sys: 3.75 ms, total: 193 ms
# Wall time: 194 ms
#                       University  \
# 0         Universidad de Granada
# 1         Universidad de Sevilla
# 2         Universidad de Granada
# 3         Universidad de Granada
# 4         Universidad de Sevilla
# 5         Universidad de Sevilla
# 6          Universidad de Málaga
# 7         Universidad de Córdoba
# 8         Universidad de Sevilla
# 9           Universidad de Cádiz
# 10        Universidad de Granada
# 11        Universidad de Granada
# 12        Universidad de Sevilla
# 13        Universidad de Sevilla
# 14  Universidad Pablo de Olavide
# 15        Universidad de Sevilla
# 16        Universidad de Sevilla
# 17        Universidad de Sevilla
# 18         Universidad de Málaga
# 19        Universidad de Sevilla
# 20  Universidad Pablo de Olavide
# 21        Universidad de Sevilla
# 22        Universidad de Sevilla
# 23        Universidad de Sevilla
# 24         Universidad de Málaga
# 25        Universidad de Granada
# 26        Universidad de Córdoba
# 27        Universidad de Granada
# 28  Universidad Pablo de Olavide
# 29        Universidad de Granada
# 30  Universidad Pablo de Olavide
# 31         Universidad de Málaga
# 32  Universidad Pablo de Olavide
# 33  Universidad Pablo de Olavide
# 34          Universidad de Cádiz
# 35          Universidad de Cádiz
# 36         Universidad de Málaga
# 37        Universidad de Sevilla
# 38        Universidad de Sevilla
# 39        Universidad de Sevilla
# 40        Universidad de Granada
# 41        Universidad de Sevilla
# 42         Universidad de Málaga
# 43        Universidad de Sevilla
# 44          Universidad de Cádiz
# 45        Universidad de Córdoba
# 46        Universidad de Granada
# 47        Universidad de Granada
# 48        Universidad de Sevilla
# 49          Universidad de Cádiz
#
#                                                Degree   Grade Province  \
# 0                 Doble Grado en Matemáticas + Física  13,164  Granada
# 1                Doble Grado en Física +  Matemáticas  13,090  Sevilla
# 2                                   Grado en Medicina  12,750  Granada
# 3       Grado en Traducción e Interpretación (Inglés)  12,750  Granada
# 4                                   Grado en Medicina  12,725  Sevilla
# 5   Doble Grado en Fisioterapia + Ciencias de la A...  12,677  Sevilla
# 6                                   Grado en Medicina  12,631   Málaga
# 7                                   Grado en Medicina  12,623  Córdoba
# 8          Grado en Biomedicina Básica y Experimental  12,562  Sevilla
# 9                                   Grado en Medicina  12,483    Cádiz
# 10                                Grado en Bioquímica  12,435  Granada
# 11                             Grado en Biotecnología  12,300  Granada
# 12                   Grado en Ingeniería Aeroespacial  12,295  Sevilla
# 13    Grado en Bioquímica (interuniversitario US-UMA)  12,250  Sevilla
# 14                             Grado en Biotecnología  12,075  Sevilla
# 15  Doble Grado en Periodismo + Comunicación Audio...  12,031  Sevilla
# 16                  Doble Grado en Derecho + Economía  12,025  Sevilla
# 17  Doble Grado en Ingeniería en Diseño Industrial...  11,970  Sevilla
# 18                                Grado en Bioquímica  11,895   Málaga
# 19                               Grado en Odontología  11,880  Sevilla
# 20  Doble Grado en Derecho + Administración y Dire...  11,870  Sevilla
# 21  Grado en Ingeniería Electrónica, Robótica y Me...  11,840  Sevilla
# 22                              Grado en Fisioterapia  11,738  Sevilla
# 23   Doble Grado en Física + Ingeniería de Materiales  11,721  Sevilla
# 24                              Grado en Fisioterapia  11,675   Málaga
# 25  Doble Grado en Ingeniería Informática + Matemá...  11,673  Granada
# 26                                Grado en Bioquímica  11,660  Córdoba
# 27                               Grado en Odontología  11,650  Granada
# 28      Grado en Traducción e Interpretación (Inglés)  11,580  Sevilla
# 29                              Grado en Fisioterapia  11,560  Granada
# 30  Doble Grado en Humanidades + Traducción e Inte...  11,544  Sevilla
# 31  Doble Grado en Economía +  Administración y Di...  11,430   Málaga
# 32    Grado en Administración y Dirección de Empresas  11,420  Sevilla
# 33              Doble Grado en Derecho + Criminología  11,375  Sevilla
# 34  Doble Grado en Filología Hispánica +  Estudios...  11,339    Cádiz
# 35                             Grado en Biotecnología  11,335    Cádiz
# 36  Grado en Ingeniería Electrónica, Robótica y Me...  11,160   Málaga
# 37                                Grado en Enfermería  11,106  Sevilla
# 38  Doble Grado en Educación Primaria + Estudios F...  11,090  Sevilla
# 39          Doble Grado en Matemáticas +  Estadística  11,035  Sevilla
# 40  Doble Grado en Educación Primaria + Estudios I...  10,982  Granada
# 41  Doble Grado en Administración y Dirección de E...  10,980  Sevilla
# 42  Doble Grado en Derecho + Administración y Dire...  10,959   Málaga
# 43  Doble Grado en Química + Ingeniería de Materiales  10,941  Sevilla
# 44  Doble Grado en Ingeniería Mecánica + Ingenierí...  10,892    Cádiz
# 45                               Grado en Veterinaria  10,863  Córdoba
# 46  Doble Grado en Traducción e Interpretación (In...  10,793  Granada
# 47  Grado en Ciencias de la Actividad Física y del...  10,790  Granada
# 48      Doble Grado en Farmacia + Óptica y Optometría  10,778  Sevilla
# 49                              Grado en Fisioterapia  10,700    Cádiz
#
#          Public/Private    Modality  \
# 0   Universidad Pública  Presencial
# 1   Universidad Pública  Presencial
# 2   Universidad Pública  Presencial
# 3   Universidad Pública  Presencial
# 4   Universidad Pública  Presencial
# 5   Universidad Pública  Presencial
# 6   Universidad Pública  Presencial
# 7   Universidad Pública  Presencial
# 8   Universidad Pública  Presencial
# 9   Universidad Pública  Presencial
# 10  Universidad Pública  Presencial
# 11  Universidad Pública  Presencial
# 12  Universidad Pública  Presencial
# 13  Universidad Pública  Presencial
# 14  Universidad Pública  Presencial
# 15  Universidad Pública  Presencial
# 16  Universidad Pública  Presencial
# 17  Universidad Pública  Presencial
# 18  Universidad Pública  Presencial
# 19  Universidad Pública  Presencial
# 20  Universidad Pública  Presencial
# 21  Universidad Pública  Presencial
# 22  Universidad Pública  Presencial
# 23  Universidad Pública  Presencial
# 24  Universidad Pública  Presencial
# 25  Universidad Pública  Presencial
# 26  Universidad Pública  Presencial
# 27  Universidad Pública  Presencial
# 28  Universidad Pública  Presencial
# 29  Universidad Pública  Presencial
# 30  Universidad Pública  Presencial
# 31  Universidad Pública  Presencial
# 32  Universidad Pública  Presencial
# 33  Universidad Pública  Presencial
# 34  Universidad Pública  Presencial
# 35  Universidad Pública  Presencial
# 36  Universidad Pública  Presencial
# 37  Universidad Pública  Presencial
# 38  Universidad Pública  Presencial
# 39  Universidad Pública  Presencial
# 40  Universidad Pública  Presencial
# 41  Universidad Pública  Presencial
# 42  Universidad Pública  Presencial
# 43  Universidad Pública  Presencial
# 44  Universidad Pública  Presencial
# 45  Universidad Pública  Presencial
# 46  Universidad Pública  Presencial
# 47  Universidad Pública  Presencial
# 48  Universidad Pública  Presencial
# 49  Universidad Pública  Presencial
#
#                                             Web  Duration           Cost
# 0             http://fciencias.ugr.es/index.php  5,0 años  no disponible
# 1                           http://fisica.us.es  5,0 años          909 €
# 2                    http://www.ugr.es/~facmed/  6,0 años          757 €
# 3                   http://www.ugr.es/~factrad/  4,0 años          757 €
# 4                       https://medicina.us.es/  6,0 años          757 €
# 5                        http://www.fefp.us.es/  5,0 años  no disponible
# 6       http://www.uma.es/facultad-de-medicina/  6,0 años          757 €
# 7                   http://www.uco.es/medicina/  6,0 años          757 €
# 8                       https://medicina.us.es/  4,0 años          757 €
# 9                 http://www.uca.es/centro/1C04  6,0 años          757 €
# 10            http://fciencias.ugr.es/index.php  4,0 años          757 €
# 11            http://fciencias.ugr.es/index.php  4,0 años          757 €
# 12                       http://www.etsi.us.es/  4,0 años          757 €
# 13                    http://biologia.us.es/es/  4,0 años          757 €
# 14               http://www.upo.es/fcex/portada  4,0 años          757 €
# 15                           http://fcom.us.es/  5,0 años          984 €
# 16                    http://www.derecho.us.es/  5,0 años        1.136 €
# 17                           https://eps.us.es/  5,0 años          757 €
# 18     https://www.uma.es/facultad-de-ciencias/  4,0 años          757 €
# 19                 http://www.odontologiaus.es/  5,0 años          757 €
# 20      https://www.upo.es/facultad-derecho/es/            no disponible
# 21                       http://www.etsi.us.es/  4,0 años          757 €
# 22                       http://www.fefp.us.es/  4,0 años          757 €
# 23                          http://fisica.us.es  5,0 años          833 €
# 24  http://www.uma.es/facultad-de-ciencias-d...  4,0 años          757 €
# 25                        http://etsiit.ugr.es/  5,0 años  no disponible
# 26  http://www.uco.es/organiza/centros/cienc...  4,0 años          757 €
# 27                   http://www.ugr.es/~odonto/  5,0 años          757 €
# 28               http://www.upo.es/fhum/portada  4,0 años          757 €
# 29             http://cienciasdelasalud.ugr.es/  4,0 años          757 €
# 30               http://www.upo.es/fhum/portada  5,0 años  no disponible
# 31  http://www.uma.es/facultad-de-ciencias-e...  4,0 años  no disponible
# 32                http://www.upo.es/fce/portada  4,0 años          757 €
# 33      https://www.upo.es/facultad-derecho/es/  5,0 años  no disponible
# 34               http://www.uca.es/centro/1C03/  5,0 años  no disponible
# 35                http://www.uca.es/centro/1C01  4,0 años          757 €
# 36                     http://www.etsii.uma.es/  4,0 años          757 €
# 37                       http://www.fefp.us.es/  4,0 años          757 €
# 38                          https://fcce.us.es/  5,0 años          984 €
# 39                   https://matematicas.us.es/  5,0 años          833 €
# 40  http://fcce.ugr.es//index.php?option=com...  5,0 años  no disponible
# 41                          http://fceye.us.es/  5,0 años        1.060 €
# 42  http://www.uma.es/facultad-de-ciencias-e...  6,0 años  no disponible
# 43              http://www.centro.us.es/quimica  5,0 años          871 €
# 44                http://www.uca.es/centro/1C11  5,0 años          757 €
# 45               http://www.uco.es/veterinaria/  5,0 años          757 €
# 46                  http://www.ugr.es/~factrad/  5,0 años  no disponible
# 47                       http://deporte.ugr.es/  4,0 años          757 €
# 48                    http://www.farmacia.us.es  6,0 años          833 €
# 49  http://www.uca.es/escuela/ciencias_salud...  4,0 años          757 €

# %%
# %%time 
aggregate(soup)
# Out:
# CPU times: user 142 ms, sys: 3.2 ms, total: 145 ms
# Wall time: 144 ms
#                       University  \
# 0         Universidad de Granada
# 1         Universidad de Sevilla
# 2         Universidad de Granada
# 3         Universidad de Granada
# 4         Universidad de Sevilla
# 5         Universidad de Sevilla
# 6          Universidad de Málaga
# 7         Universidad de Córdoba
# 8         Universidad de Sevilla
# 9           Universidad de Cádiz
# 10        Universidad de Granada
# 11        Universidad de Granada
# 12        Universidad de Sevilla
# 13        Universidad de Sevilla
# 14  Universidad Pablo de Olavide
# 15        Universidad de Sevilla
# 16        Universidad de Sevilla
# 17        Universidad de Sevilla
# 18         Universidad de Málaga
# 19        Universidad de Sevilla
# 20  Universidad Pablo de Olavide
# 21        Universidad de Sevilla
# 22        Universidad de Sevilla
# 23        Universidad de Sevilla
# 24         Universidad de Málaga
# 25        Universidad de Granada
# 26        Universidad de Córdoba
# 27        Universidad de Granada
# 28  Universidad Pablo de Olavide
# 29        Universidad de Granada
# 30  Universidad Pablo de Olavide
# 31         Universidad de Málaga
# 32  Universidad Pablo de Olavide
# 33  Universidad Pablo de Olavide
# 34          Universidad de Cádiz
# 35          Universidad de Cádiz
# 36         Universidad de Málaga
# 37        Universidad de Sevilla
# 38        Universidad de Sevilla
# 39        Universidad de Sevilla
# 40        Universidad de Granada
# 41        Universidad de Sevilla
# 42         Universidad de Málaga
# 43        Universidad de Sevilla
# 44          Universidad de Cádiz
# 45        Universidad de Córdoba
# 46        Universidad de Granada
# 47        Universidad de Granada
# 48        Universidad de Sevilla
# 49          Universidad de Cádiz
#
#                                                Degree   Grade Province  \
# 0                 Doble Grado en Matemáticas + Física  13,164  Granada
# 1                Doble Grado en Física +  Matemáticas  13,090  Sevilla
# 2                                   Grado en Medicina  12,750  Granada
# 3       Grado en Traducción e Interpretación (Inglés)  12,750  Granada
# 4                                   Grado en Medicina  12,725  Sevilla
# 5   Doble Grado en Fisioterapia + Ciencias de la A...  12,677  Sevilla
# 6                                   Grado en Medicina  12,631   Málaga
# 7                                   Grado en Medicina  12,623  Córdoba
# 8          Grado en Biomedicina Básica y Experimental  12,562  Sevilla
# 9                                   Grado en Medicina  12,483    Cádiz
# 10                                Grado en Bioquímica  12,435  Granada
# 11                             Grado en Biotecnología  12,300  Granada
# 12                   Grado en Ingeniería Aeroespacial  12,295  Sevilla
# 13    Grado en Bioquímica (interuniversitario US-UMA)  12,250  Sevilla
# 14                             Grado en Biotecnología  12,075  Sevilla
# 15  Doble Grado en Periodismo + Comunicación Audio...  12,031  Sevilla
# 16                  Doble Grado en Derecho + Economía  12,025  Sevilla
# 17  Doble Grado en Ingeniería en Diseño Industrial...  11,970  Sevilla
# 18                                Grado en Bioquímica  11,895   Málaga
# 19                               Grado en Odontología  11,880  Sevilla
# 20  Doble Grado en Derecho + Administración y Dire...  11,870  Sevilla
# 21  Grado en Ingeniería Electrónica, Robótica y Me...  11,840  Sevilla
# 22                              Grado en Fisioterapia  11,738  Sevilla
# 23   Doble Grado en Física + Ingeniería de Materiales  11,721  Sevilla
# 24                              Grado en Fisioterapia  11,675   Málaga
# 25  Doble Grado en Ingeniería Informática + Matemá...  11,673  Granada
# 26                                Grado en Bioquímica  11,660  Córdoba
# 27                               Grado en Odontología  11,650  Granada
# 28      Grado en Traducción e Interpretación (Inglés)  11,580  Sevilla
# 29                              Grado en Fisioterapia  11,560  Granada
# 30  Doble Grado en Humanidades + Traducción e Inte...  11,544  Sevilla
# 31  Doble Grado en Economía +  Administración y Di...  11,430   Málaga
# 32    Grado en Administración y Dirección de Empresas  11,420  Sevilla
# 33              Doble Grado en Derecho + Criminología  11,375  Sevilla
# 34  Doble Grado en Filología Hispánica +  Estudios...  11,339    Cádiz
# 35                             Grado en Biotecnología  11,335    Cádiz
# 36  Grado en Ingeniería Electrónica, Robótica y Me...  11,160   Málaga
# 37                                Grado en Enfermería  11,106  Sevilla
# 38  Doble Grado en Educación Primaria + Estudios F...  11,090  Sevilla
# 39          Doble Grado en Matemáticas +  Estadística  11,035  Sevilla
# 40  Doble Grado en Educación Primaria + Estudios I...  10,982  Granada
# 41  Doble Grado en Administración y Dirección de E...  10,980  Sevilla
# 42  Doble Grado en Derecho + Administración y Dire...  10,959   Málaga
# 43  Doble Grado en Química + Ingeniería de Materiales  10,941  Sevilla
# 44  Doble Grado en Ingeniería Mecánica + Ingenierí...  10,892    Cádiz
# 45                               Grado en Veterinaria  10,863  Córdoba
# 46  Doble Grado en Traducción e Interpretación (In...  10,793  Granada
# 47  Grado en Ciencias de la Actividad Física y del...  10,790  Granada
# 48      Doble Grado en Farmacia + Óptica y Optometría  10,778  Sevilla
# 49                              Grado en Fisioterapia  10,700    Cádiz
#
#       Modality       Public/Private  \
# 0   Presencial  Universidad Pública
# 1   Presencial  Universidad Pública
# 2   Presencial  Universidad Pública
# 3   Presencial  Universidad Pública
# 4   Presencial  Universidad Pública
# 5   Presencial  Universidad Pública
# 6   Presencial  Universidad Pública
# 7   Presencial  Universidad Pública
# 8   Presencial  Universidad Pública
# 9   Presencial  Universidad Pública
# 10  Presencial  Universidad Pública
# 11  Presencial  Universidad Pública
# 12  Presencial  Universidad Pública
# 13  Presencial  Universidad Pública
# 14  Presencial  Universidad Pública
# 15  Presencial  Universidad Pública
# 16  Presencial  Universidad Pública
# 17  Presencial  Universidad Pública
# 18  Presencial  Universidad Pública
# 19  Presencial  Universidad Pública
# 20  Presencial  Universidad Pública
# 21  Presencial  Universidad Pública
# 22  Presencial  Universidad Pública
# 23  Presencial  Universidad Pública
# 24  Presencial  Universidad Pública
# 25  Presencial  Universidad Pública
# 26  Presencial  Universidad Pública
# 27  Presencial  Universidad Pública
# 28  Presencial  Universidad Pública
# 29  Presencial  Universidad Pública
# 30  Presencial  Universidad Pública
# 31  Presencial  Universidad Pública
# 32  Presencial  Universidad Pública
# 33  Presencial  Universidad Pública
# 34  Presencial  Universidad Pública
# 35  Presencial  Universidad Pública
# 36  Presencial  Universidad Pública
# 37  Presencial  Universidad Pública
# 38  Presencial  Universidad Pública
# 39  Presencial  Universidad Pública
# 40  Presencial  Universidad Pública
# 41  Presencial  Universidad Pública
# 42  Presencial  Universidad Pública
# 43  Presencial  Universidad Pública
# 44  Presencial  Universidad Pública
# 45  Presencial  Universidad Pública
# 46  Presencial  Universidad Pública
# 47  Presencial  Universidad Pública
# 48  Presencial  Universidad Pública
# 49  Presencial  Universidad Pública
#
#                                             Web  Duration           Cost
# 0             http://fciencias.ugr.es/index.php  5,0 años  no disponible
# 1                           http://fisica.us.es  5,0 años          909 €
# 2                    http://www.ugr.es/~facmed/  6,0 años          757 €
# 3                   http://www.ugr.es/~factrad/  4,0 años          757 €
# 4                       https://medicina.us.es/  6,0 años          757 €
# 5                        http://www.fefp.us.es/  5,0 años  no disponible
# 6       http://www.uma.es/facultad-de-medicina/  6,0 años          757 €
# 7                   http://www.uco.es/medicina/  6,0 años          757 €
# 8                       https://medicina.us.es/  4,0 años          757 €
# 9                 http://www.uca.es/centro/1C04  6,0 años          757 €
# 10            http://fciencias.ugr.es/index.php  4,0 años          757 €
# 11            http://fciencias.ugr.es/index.php  4,0 años          757 €
# 12                       http://www.etsi.us.es/  4,0 años          757 €
# 13                    http://biologia.us.es/es/  4,0 años          757 €
# 14               http://www.upo.es/fcex/portada  4,0 años          757 €
# 15                           http://fcom.us.es/  5,0 años          984 €
# 16                    http://www.derecho.us.es/  5,0 años        1.136 €
# 17                           https://eps.us.es/  5,0 años          757 €
# 18     https://www.uma.es/facultad-de-ciencias/  4,0 años          757 €
# 19                 http://www.odontologiaus.es/  5,0 años          757 €
# 20      https://www.upo.es/facultad-derecho/es/            no disponible
# 21                       http://www.etsi.us.es/  4,0 años          757 €
# 22                       http://www.fefp.us.es/  4,0 años          757 €
# 23                          http://fisica.us.es  5,0 años          833 €
# 24  http://www.uma.es/facultad-de-ciencias-d...  4,0 años          757 €
# 25                        http://etsiit.ugr.es/  5,0 años  no disponible
# 26  http://www.uco.es/organiza/centros/cienc...  4,0 años          757 €
# 27                   http://www.ugr.es/~odonto/  5,0 años          757 €
# 28               http://www.upo.es/fhum/portada  4,0 años          757 €
# 29             http://cienciasdelasalud.ugr.es/  4,0 años          757 €
# 30               http://www.upo.es/fhum/portada  5,0 años  no disponible
# 31  http://www.uma.es/facultad-de-ciencias-e...  4,0 años  no disponible
# 32                http://www.upo.es/fce/portada  4,0 años          757 €
# 33      https://www.upo.es/facultad-derecho/es/  5,0 años  no disponible
# 34               http://www.uca.es/centro/1C03/  5,0 años  no disponible
# 35                http://www.uca.es/centro/1C01  4,0 años          757 €
# 36                     http://www.etsii.uma.es/  4,0 años          757 €
# 37                       http://www.fefp.us.es/  4,0 años          757 €
# 38                          https://fcce.us.es/  5,0 años          984 €
# 39                   https://matematicas.us.es/  5,0 años          833 €
# 40  http://fcce.ugr.es//index.php?option=com...  5,0 años  no disponible
# 41                          http://fceye.us.es/  5,0 años        1.060 €
# 42  http://www.uma.es/facultad-de-ciencias-e...  6,0 años  no disponible
# 43              http://www.centro.us.es/quimica  5,0 años          871 €
# 44                http://www.uca.es/centro/1C11  5,0 años          757 €
# 45               http://www.uco.es/veterinaria/  5,0 años          757 €
# 46                  http://www.ugr.es/~factrad/  5,0 años  no disponible
# 47                       http://deporte.ugr.es/  4,0 años          757 €
# 48                    http://www.farmacia.us.es  6,0 años          833 €
# 49  http://www.uca.es/escuela/ciencias_salud...  4,0 años          757 €
